# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import sys
print(sys.executable)
# Out:
# d:\code\python\venv\Scripts\python.exe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cols = ["R&D Spend","Administration","Marketing Spend","State","Profit"]
df = pd.read_csv("Startups.csv",names=cols)
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  R&D Spend  Administration  Marketing Spend       State     Profit
# 1   165349.2        136897.8         471784.1    New York  192261.83
# 2   162597.7       151377.59        443898.53  California  191792.06
# 3  153441.51       101145.55        407934.54     Florida  191050.39
# 4  144372.41       118671.85        383199.62    New York  182901.99

# %%
df["State"]= (df ["State"]=="florida").astype(int)

# %%
df.head
# Out:
# <bound method NDFrame.head of     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   R&D Spend  Administration  Marketing Spend      0     Profit
# 1    165349.2        136897.8         471784.1      0  192261.83
# 2    162597.7       151377.59        443898.53      0  191792.06
# 3   153441.51       101145.55        407934.54      0  191050.39
# 4   144372.41       118671.85        383199.62      0  182901.99
# 5   142107.34        91391.77        366168.42      0  166187.94
# 6    131876.9        99814.71        362861.36      0  156991.12
# 7   134615.46       147198.87        127716.82      0  156122.51
# 8   130298.13       145530.06        323876.68      0   155752.6
# 9   120542.52       148718.95        311613.29      0  152211.77
# 10  123334.88       108679.17        304981.62      0  149759.96
# 11  101913.08       110594.11        229160.95      0  146121.95
# 12  100671.96        91790.61        249744.55      0   144259.4
# ...

# %%
for label in cols[:-1]:
    plt.hist(df[df["State"]==1][label],color="blue",label="gamma",alpha=0.7,density=True)
    plt.hist(df[df["State"]==0][label],color="red",label="hadron",alpha=0.7,density=True)
    plt.title(label)
    plt.ylabel("probability")
    plt.xlabel(label)
    plt.legend()
    plt.show()
# Out:
# d:\code\python\venv\Lib\site-packages\numpy\lib\_histograms_impl.py:901: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges

# %%
train,valid,test = np.split((df.sample(frac=1)),[int(0.6*len(df)),int(0.8*len(df))])
# Out:
# d:\code\python\venv\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
def scale_database(dataframe):
    x = dataframe[dataframe.cols[:-1]].values
    y = dataframe[dataframe.cols[:-1]].values

    scaler = StandardScaler()
    x=Scaler.fit_transform(x)

    data = np.hstack((x,np.reshape(y,(-1,1))))

    return data, x,y

# %%
print(len(train[train["State"]==1]))  # gamma
print(len(train[train["State"]==0]))
# Out:
# 0
# 30
